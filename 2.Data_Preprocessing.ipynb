# %% [markdown]
# # II. Data Pre processing

# %% [markdown]
# Clean our code, keep only what we need

# %%
import pandas as pd

# %%
filename = 'ukraine-query-tweets'
tweets_df = pd.read_csv(filename +'.csv')
display(tweets_df)
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3498783795.py:2: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_df = pd.read_csv(filename +'.csv')
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 4       https://twitter.com/nerate_us/status/166587107...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 4       2023-06-05 23:59:49+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 4       1665871076746752002
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  bookmarkCount  pinned  \
# 0                  0          0  ...              0     NaN
# 1                  1          1  ...              0     NaN
# 2                  0          0  ...              1     NaN
# 3                  0          2  ...              0     NaN
# 4                  0          0  ...              0     NaN
# ...              ...        ...  ...            ...     ...
# 199995             0          5  ...              0     NaN
# 199996             0          0  ...              0     NaN
# 199997             0          0  ...              0     NaN
# 199998             1          4  ...              0     NaN
# 199999             0          1  ...              0     NaN
#
#                                                 editState  \
# 0       {'_type': 'snscrape.modules.twitter.EditState'...
# 1       {'_type': 'snscrape.modules.twitter.EditState'...
# 2       {'_type': 'snscrape.modules.twitter.EditState'...
# 3       {'_type': 'snscrape.modules.twitter.EditState'...
# 4       {'_type': 'snscrape.modules.twitter.EditState'...
# ...                                                   ...
# 199995  {'_type': 'snscrape.modules.twitter.EditState'...
# 199996  {'_type': 'snscrape.modules.twitter.EditState'...
# 199997  {'_type': 'snscrape.modules.twitter.EditState'...
# 199998  {'_type': 'snscrape.modules.twitter.EditState'...
# 199999  {'_type': 'snscrape.modules.twitter.EditState'...
#
#                                                   content  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                           outlinks              outlinksss  \
# 0                               []                     NaN
# 1                               []                     NaN
# 2                               []                     NaN
# 3                               []                     NaN
# 4       ['https://cnn.it/3OOR7cK']  https://cnn.it/3OOR7cK
# ...                            ...                     ...
# 199995                          []                     NaN
# 199996                          []                     NaN
# 199997                          []                     NaN
# 199998                          []                     NaN
# 199999                          []                     NaN
#
#                         tcooutlinks            tcooutlinksss         username  \
# 0                                []                      NaN  PeterKropotki16
# 1                                []                      NaN    aixlachapelle
# 2                                []                      NaN  No_Suffer_Fools
# 3                                []                      NaN     ddoregon2020
# 4       ['https://t.co/GYEi7tD7lY']  https://t.co/GYEi7tD7lY        nerate_us
# ...                             ...                      ...              ...
# 199995                           []                      NaN        collaisco
# 199996                           []                      NaN          robysrh
# 199997                           []                      NaN         wlcondra
# 199998                           []                      NaN      kardinal691
# 199999                           []                      NaN    AlmightyDeity
#
#                             _snscrape
# 0       0.6.2.20230321.dev50+g0d824ab
# 1       0.6.2.20230321.dev50+g0d824ab
# 2       0.6.2.20230321.dev50+g0d824ab
# 3       0.6.2.20230321.dev50+g0d824ab
# 4       0.6.2.20230321.dev50+g0d824ab
# ...                               ...
# 199995  0.6.2.20230321.dev50+g0d824ab
# 199996  0.6.2.20230321.dev50+g0d824ab
# 199997  0.6.2.20230321.dev50+g0d824ab
# 199998  0.6.2.20230321.dev50+g0d824ab
# 199999  0.6.2.20230321.dev50+g0d824ab
#
# [200000 rows x 40 columns]

# %% [markdown]
# ## 1. Convert user json column into new columns

# %%
import ast 

tweets_df.dropna(subset=['user'],inplace=True)
tweets_df['user'] = tweets_df['user'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
for key in tweets_df['user'][0].keys():
    tweets_df['user-'+key] = tweets_df['user'].apply(lambda x: x[key])
tweets_df
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 4       https://twitter.com/nerate_us/status/166587107...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 4       2023-06-05 23:59:49+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 4       1665871076746752002
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  \
# 0                  0          0  ...
# 1                  1          1  ...
# 2                  0          0  ...
# 3                  0          2  ...
# 4                  0          0  ...
# ...              ...        ...  ...
# 199995             0          5  ...
# 199996             0          0  ...
# 199997             0          0  ...
# 199998             1          4  ...
# 199999             0          1  ...
#
#                                      user-profileImageUrl  \
# 0       https://pbs.twimg.com/profile_images/158908056...
# 1       https://pbs.twimg.com/profile_images/153570353...
# 2       https://pbs.twimg.com/profile_images/160069194...
# 3       https://pbs.twimg.com/profile_images/156263582...
# 4       https://pbs.twimg.com/profile_images/163909854...
# ...                                                   ...
# 199995  https://pbs.twimg.com/profile_images/161482605...
# 199996  https://pbs.twimg.com/profile_images/161408569...
# 199997  https://pbs.twimg.com/profile_images/378800000...
# 199998  https://pbs.twimg.com/profile_images/154280650...
# 199999  https://pbs.twimg.com/profile_images/124477852...
#
#                                     user-profileBannerUrl user-label  \
# 0                                                    None       None
# 1       https://pbs.twimg.com/profile_banners/47247335...       None
# 2       https://pbs.twimg.com/profile_banners/77314551...       None
# 3       https://pbs.twimg.com/profile_banners/82359810...       None
# 4       https://pbs.twimg.com/profile_banners/16188312...       None
# ...                                                   ...        ...
# 199995  https://pbs.twimg.com/profile_banners/25084300...       None
# 199996  https://pbs.twimg.com/profile_banners/19021631...       None
# 199997                                               None       None
# 199998  https://pbs.twimg.com/profile_banners/73158758...       None
# 199999  https://pbs.twimg.com/profile_banners/47544037...       None
#
#         user-blue  user-blueType  \
# 0           False           None
# 1           False           None
# 2           False           None
# 3           False           None
# 4           False           None
# ...           ...            ...
# 199995      False           None
# 199996       True           None
# 199997      False           None
# 199998      False           None
# 199999      False           None
#
#                                          user-description  \
# 0
# 1       Do not go gentle into that good night, rage, r...
# 2       I want to live in a world where Zimmerman offe...
# 3       Mom,Nana &Dog lover/caretaker. working daily t...
# 4       Biased for the unbiased. Transparency is not a...
# ...                                                   ...
# 199995  MD, believer in treating people the way you wo...
# 199996  All opinions are mine alone. Proud $8 a month ...
# 199997
# 199998  Ukraineophile, Save Western Culture and Civili...
# 199999  Leftist MAGA. \nMy views represent no one but ...
#
#        user-descriptionUrls          user-linkTcourl  \
# 0                      None                     None
# 1                      None                     None
# 2                      None  https://t.co/5hf3BM2vFA
# 3                      None                     None
# 4                      None                     None
# ...                     ...                      ...
# 199995                 None                     None
# 199996                 None                     None
# 199997                 None                     None
# 199998                 None                     None
# 199999                 None                     None
#
#                                              user-linkUrl  \
# 0                                                    None
# 1                                                    None
# 2       https://fineartamerica.com/profiles/gallery-be...
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 199995                                               None
# 199996                                               None
# 199997                                               None
# 199998                                               None
# 199999                                               None
#
#                                    user-url
# 0       https://twitter.com/PeterKropotki16
# 1         https://twitter.com/aixlachapelle
# 2       https://twitter.com/No_Suffer_Fools
# 3          https://twitter.com/ddoregon2020
# 4             https://twitter.com/nerate_us
# ...                                     ...
# 199995        https://twitter.com/collaisco
# 199996          https://twitter.com/robysrh
# 199997         https://twitter.com/wlcondra
# 199998      https://twitter.com/kardinal691
# 199999    https://twitter.com/AlmightyDeity
#
# [200000 rows x 68 columns]

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   _type                     200000 non-null  object
#  1   url                       200000 non-null  object
#  2   date                      200000 non-null  object
#  3   rawContent                200000 non-null  object
#  4   renderedContent           200000 non-null  object
#  5   id                        200000 non-null  int64
#  6   user                      200000 non-null  object
#  7   replyCount                200000 non-null  int64
#  8   retweetCount              200000 non-null  int64
#  9   likeCount                 200000 non-null  int64
#  10  quoteCount                200000 non-null  int64
#  11  conversationId            200000 non-null  int64
#  12  lang                      200000 non-null  object
#  13  source                    0 non-null       float64
#  14  sourceUrl                 0 non-null       float64
#  15  sourceLabel               0 non-null       float64
#  16  links                     33021 non-null   object
#  17  media                     25451 non-null   object
#  18  retweetedTweet            0 non-null       float64
#  19  quotedTweet               16246 non-null   object
#  20  inReplyToTweetId          136057 non-null  float64
#  21  inReplyToUser             136057 non-null  object
#  22  mentionedUsers            139783 non-null  object
#  23  coordinates               1862 non-null    object
#  24  place                     1863 non-null    object
#  25  hashtags                  25325 non-null   object
#  26  cashtags                  134 non-null     object
#  27  card                      24725 non-null   object
#  28  viewCount                 199928 non-null  float64
#  29  vibe                      19 non-null      object
#  30  bookmarkCount             200000 non-null  int64
#  31  pinned                    0 non-null       float64
#  32  editState                 200000 non-null  object
#  33  content                   200000 non-null  object
#  34  outlinks                  200000 non-null  object
#  35  outlinksss                33021 non-null   object
#  36  tcooutlinks               200000 non-null  object
#  37  tcooutlinksss             33021 non-null   object
#  38  username                  200000 non-null  object
#  39  _snscrape                 200000 non-null  object
#  40  user-_type                200000 non-null  object
#  41  user-username             200000 non-null  object
#  42  user-id                   200000 non-null  int64
#  43  user-displayname          200000 non-null  object
#  44  user-rawDescription       200000 non-null  object
#  45  user-renderedDescription  200000 non-null  object
#  46  user-descriptionLinks     11768 non-null   object
#  47  user-verified             200000 non-null  bool
#  48  user-created              200000 non-null  object
#  49  user-followersCount       200000 non-null  int64
#  50  user-friendsCount         200000 non-null  int64
#  51  user-statusesCount        200000 non-null  int64
#  52  user-favouritesCount      200000 non-null  int64
#  53  user-listedCount          200000 non-null  int64
#  54  user-mediaCount           200000 non-null  int64
#  55  user-location             200000 non-null  object
#  56  user-protected            0 non-null       object
#  57  user-link                 43057 non-null   object
#  58  user-profileImageUrl      200000 non-null  object
#  59  user-profileBannerUrl     138753 non-null  object
#  60  user-label                547 non-null     object
#  61  user-blue                 200000 non-null  bool
#  62  user-blueType             1515 non-null    object
#  63  user-description          200000 non-null  object
#  64  user-descriptionUrls      11768 non-null   object
#  65  user-linkTcourl           43057 non-null   object
#  66  user-linkUrl              43057 non-null   object
#  67  user-url                  200000 non-null  object
# dtypes: bool(2), float64(7), int64(14), object(45)
# memory usage: 101.1+ MB

# %% [markdown]
# ## 2. Row treatment

# %% [markdown]
# Remove tweets with less than 1 retweet

# %%
mask = (tweets_df.retweetCount > 0)
tweets_df = tweets_df.loc[mask]

# %% [markdown]
# Remove tweets with link

# %%
mask = (tweets_df.outlinks == "[]")
tweets_df = tweets_df.loc[mask]

tweets_df.outlinks
# Out:
# 0         []
# 1         []
# 2         []
# 3         []
# 5         []
#           ..
# 199995    []
# 199996    []
# 199997    []
# 199998    []
# 199999    []
# Name: outlinks, Length: 166979, dtype: object

# %%
tweets_df.links = tweets_df.links.fillna(0) #remplace na by 0
mask = (tweets_df.links == 0)
tweets_df = tweets_df.loc[mask]

tweets_df
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 5       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 5       https://twitter.com/almodozo/status/1665871067...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 5       2023-06-05 23:59:47+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 5       1665871067993317376
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 5       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  \
# 0                  0          0  ...
# 1                  1          1  ...
# 2                  0          0  ...
# 3                  0          2  ...
# 5                  2          6  ...
# ...              ...        ...  ...
# 199995             0          5  ...
# 199996             0          0  ...
# 199997             0          0  ...
# 199998             1          4  ...
# 199999             0          1  ...
#
#                                      user-profileImageUrl  \
# 0       https://pbs.twimg.com/profile_images/158908056...
# 1       https://pbs.twimg.com/profile_images/153570353...
# 2       https://pbs.twimg.com/profile_images/160069194...
# 3       https://pbs.twimg.com/profile_images/156263582...
# 5       https://pbs.twimg.com/profile_images/589832983...
# ...                                                   ...
# 199995  https://pbs.twimg.com/profile_images/161482605...
# 199996  https://pbs.twimg.com/profile_images/161408569...
# 199997  https://pbs.twimg.com/profile_images/378800000...
# 199998  https://pbs.twimg.com/profile_images/154280650...
# 199999  https://pbs.twimg.com/profile_images/124477852...
#
#                                     user-profileBannerUrl user-label  \
# 0                                                    None       None
# 1       https://pbs.twimg.com/profile_banners/47247335...       None
# 2       https://pbs.twimg.com/profile_banners/77314551...       None
# 3       https://pbs.twimg.com/profile_banners/82359810...       None
# 5       https://pbs.twimg.com/profile_banners/24750623...       None
# ...                                                   ...        ...
# 199995  https://pbs.twimg.com/profile_banners/25084300...       None
# 199996  https://pbs.twimg.com/profile_banners/19021631...       None
# 199997                                               None       None
# 199998  https://pbs.twimg.com/profile_banners/73158758...       None
# 199999  https://pbs.twimg.com/profile_banners/47544037...       None
#
#         user-blue  user-blueType  \
# 0           False           None
# 1           False           None
# 2           False           None
# 3           False           None
# 5           False           None
# ...           ...            ...
# 199995      False           None
# 199996       True           None
# 199997      False           None
# 199998      False           None
# 199999      False           None
#
#                                          user-description  \
# 0
# 1       Do not go gentle into that good night, rage, r...
# 2       I want to live in a world where Zimmerman offe...
# 3       Mom,Nana &Dog lover/caretaker. working daily t...
# 5       Ex-@StgMiraMedia @OpenSociety @CEU but that's ...
# ...                                                   ...
# 199995  MD, believer in treating people the way you wo...
# 199996  All opinions are mine alone. Proud $8 a month ...
# 199997
# 199998  Ukraineophile, Save Western Culture and Civili...
# 199999  Leftist MAGA. \nMy views represent no one but ...
#
#         user-descriptionUrls          user-linkTcourl  \
# 0                       None                     None
# 1                       None                     None
# 2                       None  https://t.co/5hf3BM2vFA
# 3                       None                     None
# 5                       None                     None
# ...                      ...                      ...
# 199995                  None                     None
# 199996                  None                     None
# 199997                  None                     None
# 199998                  None                     None
# 199999                  None                     None
#
#                                              user-linkUrl  \
# 0                                                    None
# 1                                                    None
# 2       https://fineartamerica.com/profiles/gallery-be...
# 3                                                    None
# 5                                                    None
# ...                                                   ...
# 199995                                               None
# 199996                                               None
# 199997                                               None
# 199998                                               None
# 199999                                               None
#
#                                    user-url
# 0       https://twitter.com/PeterKropotki16
# 1         https://twitter.com/aixlachapelle
# 2       https://twitter.com/No_Suffer_Fools
# 3          https://twitter.com/ddoregon2020
# 5              https://twitter.com/almodozo
# ...                                     ...
# 199995        https://twitter.com/collaisco
# 199996          https://twitter.com/robysrh
# 199997         https://twitter.com/wlcondra
# 199998      https://twitter.com/kardinal691
# 199999    https://twitter.com/AlmightyDeity
#
# [166979 rows x 68 columns]

# %% [markdown]
# Check duplications

# %%
tweets_df = tweets_df.drop_duplicates(subset='rawContent')
tweets_df
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 5       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 5       https://twitter.com/almodozo/status/1665871067...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 5       2023-06-05 23:59:47+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 5       1665871067993317376
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 5       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  \
# 0                  0          0  ...
# 1                  1          1  ...
# 2                  0          0  ...
# 3                  0          2  ...
# 5                  2          6  ...
# ...              ...        ...  ...
# 199995             0          5  ...
# 199996             0          0  ...
# 199997             0          0  ...
# 199998             1          4  ...
# 199999             0          1  ...
#
#                                      user-profileImageUrl  \
# 0       https://pbs.twimg.com/profile_images/158908056...
# 1       https://pbs.twimg.com/profile_images/153570353...
# 2       https://pbs.twimg.com/profile_images/160069194...
# 3       https://pbs.twimg.com/profile_images/156263582...
# 5       https://pbs.twimg.com/profile_images/589832983...
# ...                                                   ...
# 199995  https://pbs.twimg.com/profile_images/161482605...
# 199996  https://pbs.twimg.com/profile_images/161408569...
# 199997  https://pbs.twimg.com/profile_images/378800000...
# 199998  https://pbs.twimg.com/profile_images/154280650...
# 199999  https://pbs.twimg.com/profile_images/124477852...
#
#                                     user-profileBannerUrl user-label  \
# 0                                                    None       None
# 1       https://pbs.twimg.com/profile_banners/47247335...       None
# 2       https://pbs.twimg.com/profile_banners/77314551...       None
# 3       https://pbs.twimg.com/profile_banners/82359810...       None
# 5       https://pbs.twimg.com/profile_banners/24750623...       None
# ...                                                   ...        ...
# 199995  https://pbs.twimg.com/profile_banners/25084300...       None
# 199996  https://pbs.twimg.com/profile_banners/19021631...       None
# 199997                                               None       None
# 199998  https://pbs.twimg.com/profile_banners/73158758...       None
# 199999  https://pbs.twimg.com/profile_banners/47544037...       None
#
#         user-blue  user-blueType  \
# 0           False           None
# 1           False           None
# 2           False           None
# 3           False           None
# 5           False           None
# ...           ...            ...
# 199995      False           None
# 199996       True           None
# 199997      False           None
# 199998      False           None
# 199999      False           None
#
#                                          user-description  \
# 0
# 1       Do not go gentle into that good night, rage, r...
# 2       I want to live in a world where Zimmerman offe...
# 3       Mom,Nana &Dog lover/caretaker. working daily t...
# 5       Ex-@StgMiraMedia @OpenSociety @CEU but that's ...
# ...                                                   ...
# 199995  MD, believer in treating people the way you wo...
# 199996  All opinions are mine alone. Proud $8 a month ...
# 199997
# 199998  Ukraineophile, Save Western Culture and Civili...
# 199999  Leftist MAGA. \nMy views represent no one but ...
#
#         user-descriptionUrls          user-linkTcourl  \
# 0                       None                     None
# 1                       None                     None
# 2                       None  https://t.co/5hf3BM2vFA
# 3                       None                     None
# 5                       None                     None
# ...                      ...                      ...
# 199995                  None                     None
# 199996                  None                     None
# 199997                  None                     None
# 199998                  None                     None
# 199999                  None                     None
#
#                                              user-linkUrl  \
# 0                                                    None
# 1                                                    None
# 2       https://fineartamerica.com/profiles/gallery-be...
# 3                                                    None
# 5                                                    None
# ...                                                   ...
# 199995                                               None
# 199996                                               None
# 199997                                               None
# 199998                                               None
# 199999                                               None
#
#                                    user-url
# 0       https://twitter.com/PeterKropotki16
# 1         https://twitter.com/aixlachapelle
# 2       https://twitter.com/No_Suffer_Fools
# 3          https://twitter.com/ddoregon2020
# 5              https://twitter.com/almodozo
# ...                                     ...
# 199995        https://twitter.com/collaisco
# 199996          https://twitter.com/robysrh
# 199997         https://twitter.com/wlcondra
# 199998      https://twitter.com/kardinal691
# 199999    https://twitter.com/AlmightyDeity
#
# [166235 rows x 68 columns]

# %% [markdown]
# ## 3. New features

# %% [markdown]
# Tweet char count

# %%
tweets_df['charCount'] = tweets_df['rawContent'].apply(lambda x: len(x))
tweets_df
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\2030331571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['charCount'] = tweets_df['rawContent'].apply(lambda x: len(x))
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 5       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 5       https://twitter.com/almodozo/status/1665871067...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 5       2023-06-05 23:59:47+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 5       1665871067993317376
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 5       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  \
# 0                  0          0  ...
# 1                  1          1  ...
# 2                  0          0  ...
# 3                  0          2  ...
# 5                  2          6  ...
# ...              ...        ...  ...
# 199995             0          5  ...
# 199996             0          0  ...
# 199997             0          0  ...
# 199998             1          4  ...
# 199999             0          1  ...
#
#                                     user-profileBannerUrl  user-label  \
# 0                                                    None        None
# 1       https://pbs.twimg.com/profile_banners/47247335...        None
# 2       https://pbs.twimg.com/profile_banners/77314551...        None
# 3       https://pbs.twimg.com/profile_banners/82359810...        None
# 5       https://pbs.twimg.com/profile_banners/24750623...        None
# ...                                                   ...         ...
# 199995  https://pbs.twimg.com/profile_banners/25084300...        None
# 199996  https://pbs.twimg.com/profile_banners/19021631...        None
# 199997                                               None        None
# 199998  https://pbs.twimg.com/profile_banners/73158758...        None
# 199999  https://pbs.twimg.com/profile_banners/47544037...        None
#
#        user-blue  user-blueType  \
# 0          False           None
# 1          False           None
# 2          False           None
# 3          False           None
# 5          False           None
# ...          ...            ...
# 199995     False           None
# 199996      True           None
# 199997     False           None
# 199998     False           None
# 199999     False           None
#
#                                          user-description  \
# 0
# 1       Do not go gentle into that good night, rage, r...
# 2       I want to live in a world where Zimmerman offe...
# 3       Mom,Nana &Dog lover/caretaker. working daily t...
# 5       Ex-@StgMiraMedia @OpenSociety @CEU but that's ...
# ...                                                   ...
# 199995  MD, believer in treating people the way you wo...
# 199996  All opinions are mine alone. Proud $8 a month ...
# 199997
# 199998  Ukraineophile, Save Western Culture and Civili...
# 199999  Leftist MAGA. \nMy views represent no one but ...
#
#         user-descriptionUrls          user-linkTcourl  \
# 0                       None                     None
# 1                       None                     None
# 2                       None  https://t.co/5hf3BM2vFA
# 3                       None                     None
# 5                       None                     None
# ...                      ...                      ...
# 199995                  None                     None
# 199996                  None                     None
# 199997                  None                     None
# 199998                  None                     None
# 199999                  None                     None
#
#                                              user-linkUrl  \
# 0                                                    None
# 1                                                    None
# 2       https://fineartamerica.com/profiles/gallery-be...
# 3                                                    None
# 5                                                    None
# ...                                                   ...
# 199995                                               None
# 199996                                               None
# 199997                                               None
# 199998                                               None
# 199999                                               None
#
#                                    user-url charCount
# 0       https://twitter.com/PeterKropotki16       295
# 1         https://twitter.com/aixlachapelle       140
# 2       https://twitter.com/No_Suffer_Fools       279
# 3          https://twitter.com/ddoregon2020       234
# 5              https://twitter.com/almodozo       279
# ...                                     ...       ...
# 199995        https://twitter.com/collaisco        75
# 199996          https://twitter.com/robysrh       340
# 199997         https://twitter.com/wlcondra       258
# 199998      https://twitter.com/kardinal691       120
# 199999    https://twitter.com/AlmightyDeity       311
#
# [166235 rows x 69 columns]

# %% [markdown]
# Tweet emoji count

# %%
import re

# %%
# Function to count emojis in a string
def count_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"  # Dingbats
                               u"\U000024C2-\U0001F251" 
                               "]+", flags=re.UNICODE)
    emojis = re.findall(emoji_pattern, text)
    return len(emojis)

# %%
# Apply the emoji count function to each tweet
tweets_df['emojiCount'] = tweets_df['rawContent'].apply(count_emojis)

# Access the emoji count
tweets_df
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\2937611836.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['emojiCount'] = tweets_df['rawContent'].apply(count_emojis)
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 5       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 5       https://twitter.com/almodozo/status/1665871067...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 5       2023-06-05 23:59:47+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 5       1665871067993317376
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 5       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  user-label  user-blue user-blueType  \
# 0                  0          0  ...        None      False          None
# 1                  1          1  ...        None      False          None
# 2                  0          0  ...        None      False          None
# 3                  0          2  ...        None      False          None
# 5                  2          6  ...        None      False          None
# ...              ...        ...  ...         ...        ...           ...
# 199995             0          5  ...        None      False          None
# 199996             0          0  ...        None       True          None
# 199997             0          0  ...        None      False          None
# 199998             1          4  ...        None      False          None
# 199999             0          1  ...        None      False          None
#
#                                          user-description  \
# 0
# 1       Do not go gentle into that good night, rage, r...
# 2       I want to live in a world where Zimmerman offe...
# 3       Mom,Nana &Dog lover/caretaker. working daily t...
# 5       Ex-@StgMiraMedia @OpenSociety @CEU but that's ...
# ...                                                   ...
# 199995  MD, believer in treating people the way you wo...
# 199996  All opinions are mine alone. Proud $8 a month ...
# 199997
# 199998  Ukraineophile, Save Western Culture and Civili...
# 199999  Leftist MAGA. \nMy views represent no one but ...
#
#         user-descriptionUrls          user-linkTcourl  \
# 0                       None                     None
# 1                       None                     None
# 2                       None  https://t.co/5hf3BM2vFA
# 3                       None                     None
# 5                       None                     None
# ...                      ...                      ...
# 199995                  None                     None
# 199996                  None                     None
# 199997                  None                     None
# 199998                  None                     None
# 199999                  None                     None
#
#                                              user-linkUrl  \
# 0                                                    None
# 1                                                    None
# 2       https://fineartamerica.com/profiles/gallery-be...
# 3                                                    None
# 5                                                    None
# ...                                                   ...
# 199995                                               None
# 199996                                               None
# 199997                                               None
# 199998                                               None
# 199999                                               None
#
#                                    user-url  charCount emojiCount
# 0       https://twitter.com/PeterKropotki16        295          0
# 1         https://twitter.com/aixlachapelle        140          0
# 2       https://twitter.com/No_Suffer_Fools        279          0
# 3          https://twitter.com/ddoregon2020        234          0
# 5              https://twitter.com/almodozo        279          0
# ...                                     ...        ...        ...
# 199995        https://twitter.com/collaisco         75          0
# 199996          https://twitter.com/robysrh        340          0
# 199997         https://twitter.com/wlcondra        258          0
# 199998      https://twitter.com/kardinal691        120          0
# 199999    https://twitter.com/AlmightyDeity        311          0
#
# [166235 rows x 70 columns]

# %% [markdown]
# Tweet Words Count

# %%
# Function to count words in a string
def count_words(text):
    words = text.split()
    return len(words)

# %%
tweets_df['wordCount'] = tweets_df['rawContent'].apply(count_words)
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3585388482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['wordCount'] = tweets_df['rawContent'].apply(count_words)

# %% [markdown]
# Tweet Emojis to char ratio

# %%
def calculate_emoji_ratio(row):
    char_count = row['charCount']
    emoji_count = row['emojiCount']
    if char_count > 0:
        ratio = emoji_count / char_count
    else:
        ratio = 0
    return ratio

# %%
tweets_df['emojiCharRatio'] = tweets_df.apply(calculate_emoji_ratio, axis=1)
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3403726692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['emojiCharRatio'] = tweets_df.apply(calculate_emoji_ratio, axis=1)

# %% [markdown]
# Tweet word to char ratio

# %%
# Function to calculate the ratio of words to characters
def calculate_word_ratio(row):
    word_count = row['wordCount']
    char_count = row['charCount']
    if char_count > 0:
        ratio = word_count / char_count
    else:
        ratio = 0
    return ratio

# %%
# Apply the word ratio function to each row of the DataFrame
tweets_df['wordRatio'] = tweets_df.apply(calculate_word_ratio, axis=1)
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\2495412928.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['wordRatio'] = tweets_df.apply(calculate_word_ratio, axis=1)

# %% [markdown]
# Hastags count

# %%
# Function to count hashtags in a string
def count_hashtags(text):
    hashtags = re.findall(r"#(\w+)", text)
    return len(hashtags)

# %%
# Apply the hashtag count function to each tweet
tweets_df['hashtagCount'] = tweets_df['rawContent'].apply(count_hashtags)
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\1875643536.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['hashtagCount'] = tweets_df['rawContent'].apply(count_hashtags)

# %%
tweets_df[['charCount', 'emojiCount', 'emojiCharRatio', 'wordCount', 'wordRatio', 'hashtagCount']]
# Out:
#         charCount  emojiCount  emojiCharRatio  wordCount  wordRatio  \
# 0             295           0             0.0         49   0.166102
# 1             140           0             0.0         22   0.157143
# 2             279           0             0.0         40   0.143369
# 3             234           0             0.0         45   0.192308
# 5             279           0             0.0         39   0.139785
# ...           ...         ...             ...        ...        ...
# 199995         75           0             0.0         14   0.186667
# 199996        340           0             0.0         67   0.197059
# 199997        258           0             0.0         44   0.170543
# 199998        120           0             0.0         13   0.108333
# 199999        311           0             0.0         44   0.141479
#
#         hashtagCount
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 5                  0
# ...              ...
# 199995             0
# 199996             0
# 199997             0
# 199998             3
# 199999             0
#
# [166235 rows x 6 columns]

# %% [markdown]
# Author total activity

# %%
tweets_df['user-totalActivity'] = (tweets_df['user-statusesCount'] + tweets_df['user-favouritesCount'])
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3255028487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['user-totalActivity'] = (tweets_df['user-statusesCount'] + tweets_df['user-favouritesCount'])

# %% [markdown]
# Author tweets per year

# %%
#Convert the "date" column to a pandas datetime format:
tweets_df['date'] = pd.to_datetime(tweets_df['date'])
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3569397861.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['date'] = pd.to_datetime(tweets_df['date'])

# %%
import pandas as pd
from datetime import datetime, timezone

# Convert the 'user-created' column to datetime format
tweets_df['user-created'] = pd.to_datetime(tweets_df['user-created'])

# Convert the timezone of 'user-created' column to the desired timezone
tweets_df['user-created'] = tweets_df['user-created'].dt.tz_convert(timezone.utc)

# Calculate the account age in years
current_datetime = datetime.now(timezone.utc)
tweets_df['account_age'] = (current_datetime - tweets_df['user-created']).dt.days / 365

# View the updated DataFrame
print(tweets_df)
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 5       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 5       https://twitter.com/almodozo/status/1665871067...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                             date  \
# 0      2023-06-05 23:59:58+00:00
# 1      2023-06-05 23:59:57+00:00
# 2      2023-06-05 23:59:57+00:00
# 3      2023-06-05 23:59:55+00:00
# 5      2023-06-05 23:59:47+00:00
# ...                          ...
# 199995 2023-06-02 03:16:11+00:00
# 199996 2023-06-02 03:16:03+00:00
# 199997 2023-06-02 03:15:57+00:00
# 199998 2023-06-02 03:15:54+00:00
# 199999 2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5       Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 5       1665871067993317376
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 5       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  \
# 0                  0          0  ...
# 1                  1          1  ...
# 2                  0          0  ...
# 3                  0          2  ...
# 5                  2          6  ...
# ...              ...        ...  ...
# 199995             0          5  ...
# 199996             0          0  ...
# 199997             0          0  ...
# 199998             1          4  ...
# 199999             0          1  ...
#
#                                              user-linkUrl  \
# 0                                                    None
# 1                                                    None
# 2       https://fineartamerica.com/profiles/gallery-be...
# 3                                                    None
# 5                                                    None
# ...                                                   ...
# 199995                                               None
# 199996                                               None
# 199997                                               None
# 199998                                               None
# 199999                                               None
#
#                                    user-url charCount  emojiCount  wordCount  \
# 0       https://twitter.com/PeterKropotki16       295           0         49
# 1         https://twitter.com/aixlachapelle       140           0         22
# 2       https://twitter.com/No_Suffer_Fools       279           0         40
# 3          https://twitter.com/ddoregon2020       234           0         45
# 5              https://twitter.com/almodozo       279           0         39
# ...                                     ...       ...         ...        ...
# 199995        https://twitter.com/collaisco        75           0         14
# 199996          https://twitter.com/robysrh       340           0         67
# 199997         https://twitter.com/wlcondra       258           0         44
# 199998      https://twitter.com/kardinal691       120           0         13
# 199999    https://twitter.com/AlmightyDeity       311           0         44
#
#         emojiCharRatio  wordRatio hashtagCount  user-totalActivity account_age
# 0                  0.0   0.166102            0                6426    0.627397
# 1                  0.0   0.157143            0              116325   14.030137
# 2                  0.0   0.143369            0              340886   10.838356
# 3                  0.0   0.192308            0               18195    6.413699
# 5                  0.0   0.139785            0              118492   14.276712
# ...                ...        ...          ...                 ...         ...
# 199995             0.0   0.186667            0               26667    9.098630
# 199996             0.0   0.197059            0                7525   14.441096
# 199997             0.0   0.170543            0                2685    9.808219
# 199998             0.0   0.108333            3               32398    7.109589
# 199999             0.0   0.141479            0               61861   11.410959
#
# [166235 rows x 76 columns]
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3049984811.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['user-created'] = pd.to_datetime(tweets_df['user-created'])
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3049984811.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['user-created'] = tweets_df['user-created'].dt.tz_convert(timezone.utc)
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\3049984811.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['account_age'] = (current_datetime - tweets_df['user-created']).dt.days / 365

# %%
# Create the new feature 'Author Tweets per Year'
tweets_df['user-tweetsPerYear'] = tweets_df['user-statusesCount'] / tweets_df['account_age']
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\1954568902.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['user-tweetsPerYear'] = tweets_df['user-statusesCount'] / tweets_df['account_age']

# %% [markdown]
# Author Total Activity per year

# %%
tweets_df['user-totalActivityPerYear'] = tweets_df['user-totalActivity'] / tweets_df['account_age']
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\680852059.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['user-totalActivityPerYear'] = tweets_df['user-totalActivity'] / tweets_df['account_age']

# %%
tweets_df[['user-totalActivity','user-tweetsPerYear','user-totalActivityPerYear']]
# Out:
#         user-totalActivity  user-tweetsPerYear  user-totalActivityPerYear
# 0                     6426         4442.161572               10242.314410
# 1                   116325         1512.814880                8291.080844
# 2                   340886        12836.079373               31451.817492
# 3                    18195         1987.152926                2836.896625
# 5                   118492         2823.549223                8299.669929
# ...                    ...                 ...                        ...
# 199995               26667         1221.172840                2930.880759
# 199996                7525          489.575033                 521.082337
# 199997                2685          266.715084                 273.750000
# 199998               32398         4045.803468                4556.944123
# 199999               61861         1728.338535                5421.192077
#
# [166235 rows x 3 columns]

# %% [markdown]
# Comment

# %%
#TODO Faire qu'une seule fonction pour les ratio

# %% [markdown]
# ## 4. Choose interesting columns

# %% [markdown]
# 2 features for the text, the difference are explained :
#
# - rawContent: This is the raw content of the tweet as it is stored in the Twitter database. It includes the text of the tweet, hashtags, user mentions, and links in the form of unformatted raw text. The "rawContent" does not include images, videos, or any other multimedia content.
#
# - renderedContent: This is the content of the tweet rendered in a formatted way, ready to be displayed in a browser or user interface. It may include clickable links, user mentions as links to their profiles, formatted hashtags, embedded images, videos, and more. The "renderedContent" is designed to be visually appealing and user-friendly for the end user.
#
# ➡️ utilisation of **raw Content**

# %% [markdown]
# # SOME TO DO LIST

# %% [markdown]
# Not enough time but some of todo that we could have tried :

# %% [markdown]
# - Having a picture can influence people behavior ? Having no picture reduce the number of RTs?

# %%
#TODO : TRANSFORM THE COLUMN TO PUT 1 IF IT HAS A PICTURE AND 0 IF NOT (NOT ENOUGH TIME BUT WE COULD ANALYSE THE PICTURE AND GET SOME FEATURES, FOR INSTANCE SOME PP HAVE IMPACTS ON USER S RT)

# %% [markdown]
# - European people will have more RT on their tweets ? What about Ukrainien themself ? Or russian or polish?

# %%
#TODO : Analyse the impact of the localisation, calculate the number of km bewteen people and Ukraine

# %% [markdown]
# - Dates have influence? Month ? After some crisis ? Moment of the day ? Most retweeted tweets were at the beginning?

# %%
#TODO : Analyse the impact of the date, separate day and hour of the day

# %% [markdown]
# - Does a long-time user of Twitter generally have more influence or less influence than a new user? Is it the opposite? Or is there no impact between the date of arrival and influence?

# %%
#TODO exploit user-created column : transform it to number of day since creation

# %% [markdown]
# # FEATURES FOR NUMERICAL ANALYSIS

# %%
profil_features = ['replyCount','likeCount', 'user-followersCount', 'user-friendsCount', 'user-statusesCount', 'user-favouritesCount', 'user-listedCount', 'user-mediaCount', 'charCount', 'emojiCount', 'emojiCharRatio', 'wordCount', 'wordRatio', 'hashtagCount', 'user-totalActivity','user-tweetsPerYear','user-totalActivityPerYear']

# %% [markdown]
# Using profil feature to do some analyse

# %%
profil_features_rt_predict_column = profil_features
profil_features_rt_predict_column.append('retweetCount')
profil_features_rt_predict_df = tweets_df[profil_features_rt_predict_column]
profil_features_rt_predict_df
# Out:
#         replyCount  likeCount  user-followersCount  user-friendsCount  \
# 0                0          0                   59                487
# 1                0          1                  417                863
# 2                1          0                22729              23589
# 3                1          2                 1625               2953
# 5                0          6                 1920               2207
# ...            ...        ...                  ...                ...
# 199995           2          5                 4054               3917
# 199996           1          0                  507                954
# 199997           0          0                   12                 28
# 199998           0          4                 1739               2320
# 199999           3          1                  381               1034
#
#         user-statusesCount  user-favouritesCount  user-listedCount  \
# 0                     2787                  3639                 1
# 1                    21225                 95100                 0
# 2                   139122                201764                46
# 3                    12745                  5450                 8
# 5                    40311                 78181                87
# ...                    ...                   ...               ...
# 199995               11111                 15556                 2
# 199996                7070                   455                44
# 199997                2616                    69                 0
# 199998               28764                  3634                31
# 199999               19722                 42139                 3
#
#         user-mediaCount  charCount  emojiCount  emojiCharRatio  wordCount  \
# 0                    46        295           0             0.0         49
# 1                    44        140           0             0.0         22
# 2                  3213        279           0             0.0         40
# 3                   756        234           0             0.0         45
# 5                  7865        279           0             0.0         39
# ...                 ...        ...         ...             ...        ...
# 199995              285         75           0             0.0         14
# 199996             1407        340           0             0.0         67
# 199997               12        258           0             0.0         44
# 199998            14281        120           0             0.0         13
# 199999              399        311           0             0.0         44
#
#         wordRatio  hashtagCount  user-totalActivity  user-tweetsPerYear  \
# 0        0.166102             0                6426         4442.161572
# 1        0.157143             0              116325         1512.814880
# 2        0.143369             0              340886        12836.079373
# 3        0.192308             0               18195         1987.152926
# 5        0.139785             0              118492         2823.549223
# ...           ...           ...                 ...                 ...
# 199995   0.186667             0               26667         1221.172840
# 199996   0.197059             0                7525          489.575033
# 199997   0.170543             0                2685          266.715084
# 199998   0.108333             3               32398         4045.803468
# 199999   0.141479             0               61861         1728.338535
#
#         user-totalActivityPerYear  retweetCount
# 0                    10242.314410             0
# 1                     8291.080844             1
# 2                    31451.817492             0
# 3                     2836.896625             0
# 5                     8299.669929             2
# ...                           ...           ...
# 199995                2930.880759             0
# 199996                 521.082337             0
# 199997                 273.750000             0
# 199998                4556.944123             1
# 199999                5421.192077             0
#
# [166235 rows x 18 columns]

# %% [markdown]
# # SAVE IT INTO A CSV

# %%
profil_features_rt_predict_df = profil_features_rt_predict_df[profil_features_rt_predict_df['retweetCount']>20]

# %%
profil_features_rt_predict_df.to_csv('numerical.csv', index = False)

# %%
profil_features_rt_predict_df
# Out:
#         replyCount  likeCount  user-followersCount  user-friendsCount  \
# 49              10        168               145393               1152
# 65              22         55                29935                 50
# 161             24        110             25710978               1241
# 174             65       1541               244166               3555
# 355             24        235               209526                791
# ...            ...        ...                  ...                ...
# 199473          36        210               307666               1409
# 199586           5        225               170496              15413
# 199688           5        140               307666               1409
# 199835          15        733                49426               2218
# 199873          70        937               127141              52619
#
#         user-statusesCount  user-favouritesCount  user-listedCount  \
# 49                   20108                 10651              2935
# 65                    2771                  5333                81
# 161                1029462                   739            137924
# 174                 146979                 77861              2087
# 355                 140545                  7186              1399
# ...                    ...                   ...               ...
# 199473              127234                  7327              4078
# 199586              144368                 84318              3277
# 199688              127234                  7327              4078
# 199835               26935                 33794               516
# 199873              103594                158657               199
#
#         user-mediaCount  charCount  emojiCount  emojiCharRatio  wordCount  \
# 49                 6585        172           0             0.0         27
# 65                  370        238           0             0.0         36
# 161              791619        219           0             0.0         31
# 174                8314        838           0             0.0        135
# 355               52600        422           0             0.0         73
# ...                 ...        ...         ...             ...        ...
# 199473            12022        291           0             0.0         46
# 199586             8228        273           0             0.0         43
# 199688            12022        236           0             0.0         36
# 199835             4157        221           0             0.0         34
# 199873            40952        125           0             0.0         23
#
#         wordRatio  hashtagCount  user-totalActivity  user-tweetsPerYear  \
# 49       0.156977             0               30759         2115.106628
# 65       0.151261             0                8104          213.558910
# 161      0.141553             0             1030201        63279.493095
# 174      0.161098             0              224840        10212.704169
# 355      0.172986             0              147731        34199.283333
# ...           ...           ...                 ...                 ...
# 199473   0.158076             0              134561         8905.160115
# 199586   0.157509             0              228686        10283.825137
# 199688   0.152542             0              134561         8905.160115
# 199835   0.153846             0               60729         1963.898322
# 199873   0.184000             0              262251        66104.562937
#
#         user-totalActivityPerYear  retweetCount
# 49                    3235.456772            32
# 65                     624.569257            22
# 161                  63324.918323            26
# 174                  15622.806016           309
# 355                  35947.876667            63
# ...                           ...           ...
# 199473                9417.979866            38
# 199586               16290.083919            42
# 199688                9417.979866            22
# 199835                4427.903516            34
# 199873              167345.480769           143
#
# [2915 rows x 18 columns]

# %%
tweets_df.to_csv(filename +'-cleaned.csv', index = False)

# %% [markdown]
# # FEATURES FOR TEXTUAL ANALYSIS

# %%
columns_to_add = ['retweetCount','rawContent']

# %%
tweet_content_rt_predict_df = tweets_df[columns_to_add]

# %%
tweet_content_rt_predict_df
# Out:
#         retweetCount                                         rawContent
# 0                  0  To understand RU's strategy regarding Ukraine ...
# 1                  1  @SecBlinken @TiranaHassan @hrw Human right sho...
# 2                  0  @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3                  0  @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 5                  2  Russia: &lt;invades Ukraine&gt;\n\nAlso Russia...
# ...              ...                                                ...
# 199995             0  @LePapillonBlu2 He’d have a hard time finding ...
# 199996             0  I don't give a fuck about Ukraine and Russia t...
# 199997             0  @BernieSanders What a dumb comment. Your debt ...
# 199998             1  another 15 such little helpers are waiting for...
# 199999             0  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
# [166235 rows x 2 columns]

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    text = re.sub(r'[^A-Za-z]', ' ', text)
    text = text.lower()

    words = text.split()
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]

    processed_text = ' '.join(words)

    return processed_text

tweets_df['processedText'] = tweets_df['rawContent'].apply(preprocess_text)
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\1447471308.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['processedText'] = tweets_df['rawContent'].apply(preprocess_text)

# %%
tweets_df.processedText
# Out:
# 0         understand ru strategy regarding ukraine colle...
# 1         secblinken tiranahassan hrw human right centra...
# 2         truthhunter moravian jimross omarthegreat mike...
# 3         cavemaninasuit repclayhiggins giuliani flew uk...
# 5         russia lt invades ukraine gt also russia lt su...
#                                 ...
# 199995     lepapillonblu hard time finding ukraine map hour
# 199996    give fuck ukraine russia fucking corrupt count...
# 199997    berniesanders dumb comment debt struggling pol...
# 199998    another little helper waiting delivery ukraine...
# 199999    rumstralala sweetscience oryxspioenkop cheap k...
# Name: processedText, Length: 166235, dtype: object

# %% [markdown]
# Most used words in our tweet collection

# %%
from collections import Counter

all_text = ' '.join(tweets_df['processedText'])

words = all_text.split()

word_counts = Counter(words)

most_common_words = word_counts.most_common(20)  

for word, count in most_common_words:
    print(f'{word}: {count}')
# Out:
# ukraine: 189894
# russia: 54471
# war: 33744
# russian: 27038
# co: 20308
# u: 20228
# http: 20055
# nato: 16296
# putin: 14391
# people: 14019
# would: 13072
# like: 12654
# country: 12564
# ukrainian: 12317
# amp: 10637
# support: 10317
# one: 9674
# money: 9259
# nazi: 9114
# want: 9072

# %% [markdown]
# Most used words of tweets retweeted > 100 times

# %%
high_retweet_tweets = tweets_df[tweets_df['retweetCount'] > 100]

from collections import Counter

all_text = ' '.join(high_retweet_tweets['processedText'])

words = all_text.split()

word_counts = Counter(words)

most_common_words = word_counts.most_common(20)  

for word, count in most_common_words:
    print(f'{word}: {count}')
# Out:
# ukraine: 1108
# co: 502
# http: 499
# russia: 372
# russian: 319
# war: 228
# ukrainian: 185
# u: 166
# force: 126
# military: 96
# support: 92
# amp: 87
# people: 85
# nato: 84
# putin: 78
# armed: 76
# defense: 75
# state: 69
# like: 65
# nazi: 63

# %%
tweet_content_rt_predict_df["rawContent"] = tweets_df.processedText
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_9116\2079649182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweet_content_rt_predict_df["rawContent"] = tweets_df.processedText

# %%
tweet_content_rt_predict_df["rawContent"]
# Out:
# 0         understand ru strategy regarding ukraine colle...
# 1         secblinken tiranahassan hrw human right centra...
# 2         truthhunter moravian jimross omarthegreat mike...
# 3         cavemaninasuit repclayhiggins giuliani flew uk...
# 5         russia lt invades ukraine gt also russia lt su...
#                                 ...
# 199995     lepapillonblu hard time finding ukraine map hour
# 199996    give fuck ukraine russia fucking corrupt count...
# 199997    berniesanders dumb comment debt struggling pol...
# 199998    another little helper waiting delivery ukraine...
# 199999    rumstralala sweetscience oryxspioenkop cheap k...
# Name: rawContent, Length: 166235, dtype: object

# %%
tweet_content_rt_predict_df.to_csv(filename+'-textual-rt.csv', index = False)
