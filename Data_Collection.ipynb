# %% [markdown]
# # I. DATA COLLECTION 📊

# %% [markdown]
# Data collection inspired by [Scraping historical tweets without a Twitter Developer Account's blog](https://mihaelagrigore.medium.com/scraping-historical-tweets-without-a-twitter-developer-account-79a2c61f76ab)

# %% [markdown]
# ## 1. Import necessary librairies

# %%
import os
import subprocess

import json
import csv

import uuid

from IPython.display import display_javascript, display_html, display

import pandas as pd
import numpy as np

from datetime import datetime, date, time

# %% [markdown]
# ## 2. Install snscrape and import sntwitter

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\louis\appdata\local\temp\pip-req-build-_e845o89
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 0d824ab77334ed4ab6250e5e491171afeccfb298
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: filelock in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (3.12.0)
# Requirement already satisfied: requests[socks] in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (2.31.0)
# Requirement already satisfied: lxml in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->snscrape==0.6.2.20230321.dev50+g0d824ab) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\louis\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (1.7.1)
# Building wheels for collected packages: snscrape
#   Building wheel for snscrape (pyproject.toml): started
#   Building wheel for snscrape (pyproject.toml): finished with status 'done'
#   Created wheel for snscrape: filename=snscrape-0.6.2.20230321.dev50+g0d824ab-py3-none-any.whl size=74952 sha256=50c6e6e84abca7d708229f433fe7ddcd85728d01d4c9f4ad8fe6cc6b3965dd5a
#   Stored in directory: C:\Users\louis\AppData\Local\Temp\pip-ephem-wheel-cache-0zrfvajq\wheels\05\e9\f7\57056e7c7e44b1feed932fa49fdec9d706c4f563e37160ab74
# Successfully built snscrape
# Installing collected packages: snscrape
#   Attempting uninstall: snscrape
#     Found existing installation: snscrape 0.6.2.20230321.dev39+gc3b216c
#     Uninstalling snscrape-0.6.2.20230321.dev39+gc3b216c:
#       Successfully uninstalled snscrape-0.6.2.20230321.dev39+gc3b216c
# Successfully installed snscrape-0.6.2.20230321.dev50+g0d824ab
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\louis\AppData\Local\Temp\pip-req-build-_e845o89'
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\louis\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import snscrape.modules.twitter as sntwitter

# %% [markdown]
# ## 3. Write our query

# %% [markdown]
# We wanted to collect tweet about Ukraine.
#
#
# Parameters from the following request :
#
# - jsonl: This option specifies the output format as JSONL (JSON Lines). JSONL is a format where each line of the file contains a valid JSON object. It is commonly used for storing a large number of records, such as tweets, in a compact and efficient manner.
#
# - max-results : This option sets the maximum number of results to retrieve.
#
# - lang : choose tweets from a specific langage
#
# - twitter-search '#ukraine': This part of the command specifies the search query. It searches for tweets on Twitter using the specified search criteria. In this example, it searches for tweets posted with Ukraine's hashtag.
#
# - ukraine-query-tweets.json: This redirects the output of the command to the given file. The retrieved tweets will be saved in this file in JSONL format
#
# - since / until : to have a window which delimits tweet in time

# %%
json_filename = 'ukraine-query-tweets.json'

#Using the OS library to call CLI commands in Python
os.system(f'snscrape --max-results 200000 --jsonl --progress --since 2022-12-01 twitter-search "ukraine lang:en until:2023-06-06 " > {json_filename}')
# Out:
# 0

# %% [markdown]
# ## 4. JSON and CSV convertions

# %%
filename = 'ukraine-query-tweets'
tweets_df = pd.read_json(filename +'.json', lines=True)
tweets_df.shape
# Out:
# (200000, 40)

# %%
tweets_df.to_csv(filename +'.csv', index = False)

# %%
import pandas as pd

# Lire le fichier CSV et créer un dataframe
tweets_df = pd.read_csv(filename +'.csv')
# Out:
# C:\Users\louis\AppData\Local\Temp\ipykernel_18240\1719256102.py:4: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets_df = pd.read_csv(filename +'.csv')

# %%
# Afficher le dataframe
display(tweets_df)
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 199995  snscrape.modules.twitter.Tweet
# 199996  snscrape.modules.twitter.Tweet
# 199997  snscrape.modules.twitter.Tweet
# 199998  snscrape.modules.twitter.Tweet
# 199999  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/PeterKropotki16/status/166...
# 1       https://twitter.com/aixlachapelle/status/16658...
# 2       https://twitter.com/No_Suffer_Fools/status/166...
# 3       https://twitter.com/ddoregon2020/status/166587...
# 4       https://twitter.com/nerate_us/status/166587107...
# ...                                                   ...
# 199995  https://twitter.com/collaisco/status/166447094...
# 199996  https://twitter.com/robysrh/status/16644709059...
# 199997  https://twitter.com/wlcondra/status/1664470881...
# 199998  https://twitter.com/kardinal691/status/1664470...
# 199999  https://twitter.com/AlmightyDeity/status/16644...
#
#                              date  \
# 0       2023-06-05 23:59:58+00:00
# 1       2023-06-05 23:59:57+00:00
# 2       2023-06-05 23:59:57+00:00
# 3       2023-06-05 23:59:55+00:00
# 4       2023-06-05 23:59:49+00:00
# ...                           ...
# 199995  2023-06-02 03:16:11+00:00
# 199996  2023-06-02 03:16:03+00:00
# 199997  2023-06-02 03:15:57+00:00
# 199998  2023-06-02 03:15:54+00:00
# 199999  2023-06-02 03:15:53+00:00
#
#                                                rawContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                                           renderedContent  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                          id  \
# 0       1665871111735705600
# 1       1665871111152873472
# 2       1665871108824866817
# 3       1665871099567939586
# 4       1665871076746752002
# ...                     ...
# 199995  1664470942733705216
# 199996  1664470905937100801
# 199997  1664470881698193408
# 199998  1664470868267810817
# 199999  1664470868108406785
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 199995  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 199996  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 199997  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199998  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 199999  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#         retweetCount  likeCount  ...  bookmarkCount  pinned  \
# 0                  0          0  ...              0     NaN
# 1                  1          1  ...              0     NaN
# 2                  0          0  ...              1     NaN
# 3                  0          2  ...              0     NaN
# 4                  0          0  ...              0     NaN
# ...              ...        ...  ...            ...     ...
# 199995             0          5  ...              0     NaN
# 199996             0          0  ...              0     NaN
# 199997             0          0  ...              0     NaN
# 199998             1          4  ...              0     NaN
# 199999             0          1  ...              0     NaN
#
#                                                 editState  \
# 0       {'_type': 'snscrape.modules.twitter.EditState'...
# 1       {'_type': 'snscrape.modules.twitter.EditState'...
# 2       {'_type': 'snscrape.modules.twitter.EditState'...
# 3       {'_type': 'snscrape.modules.twitter.EditState'...
# 4       {'_type': 'snscrape.modules.twitter.EditState'...
# ...                                                   ...
# 199995  {'_type': 'snscrape.modules.twitter.EditState'...
# 199996  {'_type': 'snscrape.modules.twitter.EditState'...
# 199997  {'_type': 'snscrape.modules.twitter.EditState'...
# 199998  {'_type': 'snscrape.modules.twitter.EditState'...
# 199999  {'_type': 'snscrape.modules.twitter.EditState'...
#
#                                                   content  \
# 0       To understand RU's strategy regarding Ukraine ...
# 1       @SecBlinken @TiranaHassan @hrw Human right sho...
# 2       @TruthHunter7778 @moravian63 @jimross03941273 ...
# 3       @CavemanInASuit @RepClayHiggins Giuliani flew ...
# 4       Nikki Haley says backing Ukraine is about prot...
# ...                                                   ...
# 199995  @LePapillonBlu2 He’d have a hard time finding ...
# 199996  I don't give a fuck about Ukraine and Russia t...
# 199997  @BernieSanders What a dumb comment. Your debt ...
# 199998  another 15 such little helpers are waiting for...
# 199999  @RumsTralala @SweetScience75 @oryxspioenkop Ch...
#
#                           outlinks              outlinksss  \
# 0                               []                     NaN
# 1                               []                     NaN
# 2                               []                     NaN
# 3                               []                     NaN
# 4       ['https://cnn.it/3OOR7cK']  https://cnn.it/3OOR7cK
# ...                            ...                     ...
# 199995                          []                     NaN
# 199996                          []                     NaN
# 199997                          []                     NaN
# 199998                          []                     NaN
# 199999                          []                     NaN
#
#                         tcooutlinks            tcooutlinksss         username  \
# 0                                []                      NaN  PeterKropotki16
# 1                                []                      NaN    aixlachapelle
# 2                                []                      NaN  No_Suffer_Fools
# 3                                []                      NaN     ddoregon2020
# 4       ['https://t.co/GYEi7tD7lY']  https://t.co/GYEi7tD7lY        nerate_us
# ...                             ...                      ...              ...
# 199995                           []                      NaN        collaisco
# 199996                           []                      NaN          robysrh
# 199997                           []                      NaN         wlcondra
# 199998                           []                      NaN      kardinal691
# 199999                           []                      NaN    AlmightyDeity
#
#                             _snscrape
# 0       0.6.2.20230321.dev50+g0d824ab
# 1       0.6.2.20230321.dev50+g0d824ab
# 2       0.6.2.20230321.dev50+g0d824ab
# 3       0.6.2.20230321.dev50+g0d824ab
# 4       0.6.2.20230321.dev50+g0d824ab
# ...                               ...
# 199995  0.6.2.20230321.dev50+g0d824ab
# 199996  0.6.2.20230321.dev50+g0d824ab
# 199997  0.6.2.20230321.dev50+g0d824ab
# 199998  0.6.2.20230321.dev50+g0d824ab
# 199999  0.6.2.20230321.dev50+g0d824ab
#
# [200000 rows x 40 columns]

# %% [markdown]
# ## 6. Play with dataset !

# %% [markdown]
# Counting the number of Tweets we scraped

# %%
num = sum(1 for line in open(json_filename))
print(num)
# Out:
# 200000

# %% [markdown]
# Check tweets for a particular text, here "juste"

# %%
substring = 'juste'

count = 0
f = open(json_filename, 'r')
for i, line in enumerate(f):
    if substring in line:
        count = count + 1
        obj = json.loads(line)
        print(f'Tweet number {count}: {obj["content"]}')
print(count)
f.close()
# Out:
# Tweet number 19: Ukraine, they adjusted the fire and destroyed another 84 units of enemy weapons. Among them: 7 tanks, 6 "Grads" and 6 self-propelled guns, 11 guns, 21 armored vehicles and other equipment.
#
# Let's destroy the occupiers to complete Victory!
# Tweet number 20: @WJGESQ1 @prchilly @SubtleBeats @justessb @areidross What a clown you are.
# Ukraine's defending its country from an invading army. They are fighting for the land and their lives.
# The only ignorance here is you thinking that poohtin would be happy with another land grab. He won't they will just keep invading... https://t.co/GOdVNkT5D9
# Tweet number 21: @WJGESQ1 @prchilly @SubtleBeats @justessb @areidross What a stupid question. The ukrainians can quit whenever they want. They don't want to because they know what it's like to live under Russia's brutal regime. It's why the baltic countries are staunch supporters of Ukraine!
# Tweet number 22: @Zbuczyn2137 @JarkkoKuori @GeromanAT Post your proof. It's Ukranian propaganda.
#
# But you seem smart and well-adjusted 😂😂😂 Ukraine is totally winning https://t.co/YTPsR6eUzu
# Tweet number 23: @prchilly @Give_Up_On_Name @SubtleBeats @justessb @areidross Ukraine needs to learn that ignorance isn’t a virtue.  Neither is panhandling
# Tweet number 24: @prchilly @Give_Up_On_Name @SubtleBeats @justessb @areidross Ukraine must seek peace ☮️
# Tweet number 25: @prchilly @Give_Up_On_Name @SubtleBeats @justessb @areidross Show us your “pro UKraine” post prior to 2/2022, if you dare.
# Tweet number 26: @Give_Up_On_Name @prchilly @SubtleBeats @justessb @areidross Ukraine needs to seek peace ☮️
# Tweet number 27: The 2.5x cash adjusted PE may not reflect:
# - Tailwind of East/Central Europe unity driven by the terrible situation Ukraine
# - Tailwind of fast growing online community and ad revenues
# - Recent announcement of 11k ECC visitors in 2023 vs 9k in 2022
# Tweet number 28: of 122-mm D-30 howitzers destroyed the infantry of the Armed Forces of Ukraine, who had settled in a private sector on the outskirts of a settlement north of Artyomovsk. After the first shots, the fire was adjusted to inflict maximum fire damage on the enemy.
# Tweet number 29: 🕵️‍♂️
#
# #Russia is spending surprisingly little on its war on #Ukraine
#
# The direct fiscal cost of the war — spending on soldiers and machines — is estimated to be about 3% of Russia's GDP, or roughly $67 billion a year, according to the report mentioned in Business Insider. https://t.co/GFFS03uoVc
# Tweet number 30: 🕵️‍♂️
#
# (1/2) Every decision we make in #Ukraine seems to be aimed at prolonging the war &amp; maximizing bloodshed.”
#
# Gathered statements from #USA presidential candidate Robert F. Kennedy Jr. “We destroyed this small country [Ukraine] in a conflict that we could have resolved early.” https://t.co/K4HsfFXdjU
# Tweet number 31: @WarMonitors China juste ask Russian to leave Ukraine AND Crimea and the war will end. Simple as this.
# Tweet number 32: 🕵️‍♂️
#
# The Spanish University of Alicante has canceled an exhibition by the Ukrainian soldier and photographer Dmitri Kozatski following the controversy around him being sympathetic to neo-Nazi ideology.
#
# Did you hear that from the #MSM ❓#Spain #Ukraine https://t.co/nMeinlh5PV
# Tweet number 33: @justessb @lorinthe @areidross It's not Russian propaganda. It's the reality; Ukraine has a far-right problem. You see it even in Western media; patches, armbands, flags. And even a basic history of Azov tells the same story.
# Tweet number 44: And in cooperation with the artillerymen of the Armed Forces of Ukraine, they adjusted the fire and destroyed another 84 units of enemy weapons.  Among them: 7 tanks, 6 "Grads" and 6 self-propelled guns, 11 guns, 21 armored vehicles and other equipment.
# Tweet number 45: @DagnyTaggart963 @thesiriusreport It would be adjusted depending on the amount of arms supplied to Ukraine. All money would then be used to fund the families of Russian soldiers fallen or injured in that war for life.
# Tweet number 46: @fawfulfan pandemic bottlenecks finally clearing/ppl adjusted to the ukraine war + pandemic savings spending still strong (consistent demand) means we’re finally continuing the bull run of 2017-2020 🎉
# Tweet number 47: @tedlieu Other than keeping his son Hunter afloat in Ukraine, Joe Biden hasn’t created any new, net jobs when adjusted for Government-forced Covid closures, and for population growth in the past 3 years. Also, there was a drop of 6 million employed from 2021-2022. It’s a bad record, bruh.
# Tweet number 48: The difference:
# Ukraine will have adjusted its training after this …
# that’s beyond the capacity of Russians.
# Tweet number 49: @globepolitics @Patriotsamo What about Ukraine?
# Tweet number 50: US money to Ukraine who sells guns to cartels for cash.
#
# #ThankBiden
# Tweet number 51: @ghazibousselmi1 @putinacoffin @AdamHutchings12 No we hate people like Putin who bomb Women and Children and send into Ukraine child raping Russian soldiers.. We hate Putin who starts wars, down's passenger Airlines with civilians on it, sends the world into global financial crisis because of his actions, list goes in.
# Tweet number 52: @JustinTrudeau You say that but sent billions$$$ in weapons, ammo, armored vehicules, tanks, money, military formation to Ukraine while Zelensky sends his people to die for a war he started by himself through an abolished peace treaty that was active for almost a decade.
# Tweet number 53: The UN's Food &amp; Agriculture Organisation reports World food prices have dropped "significantly" (in real terms, ie inflation adjusted) since their peak after Russia invaded Ukraine, but its still up 25% from 2020 prices, &amp; *the most expensive since 1975*... https://t.co/aqdNMLRfwO
# Tweet number 54: Ukraine: Over 1,500 children killed or injured, concern rises over forced transfers https://t.co/Rdfx3fOBBE
# #Ukraine #UkraineWar #UkraineChildren
# Tweet number 55: @NoMoreNATO Special Report 23/2021: Reducing grand corruption in Ukraine: several EU initiatives, but still insufficient results
# 23/09/2021
#
# fact for EU USA
# etc supporter
#  https://t.co/3TiQHz8oAr
# Tweet number 56: Aller faut donner 100M a l'Ukraine encore @EmmanuelMacron
# 56

# %%
tweets_df.iloc[0].content
# Out:
# "To understand RU's strategy regarding Ukraine and against the collective West, you just need to look at this GIF. The dog denies the fire and endures the heat but believes that eventually the wood will burn out, the flames will disappear, and a new house will be rebuilt. https://t.co/PZawq7ji0q"

# %% [markdown]
# Links mentioned in the tweet are also listed separately in the outlinks column.

# %%
tweets_df.iloc[0].outlinks
# Out:
# '[]'

# %%
popularity_columns = ['replyCount', 'retweetCount', 'likeCount', 'quoteCount']
tweets_df.iloc[0][popularity_columns]
# Out:
# replyCount      0
# retweetCount    0
# likeCount       0
# quoteCount      0
# Name: 0, dtype: object

# %% [markdown]
# Find the most retweeted tweet in our dataset.

# %%
tweets_df.iloc[tweets_df.retweetCount.idxmax()][['content','retweetCount']]
# Out:
# content         I wish the U.S. government supported its citiz...
# retweetCount                                                 4891
# Name: 43499, dtype: object
